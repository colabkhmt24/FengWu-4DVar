# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !git clone "https://github.com/DuckyMomo20012/FengWu-4DVar.git"
# Out:
# Cloning into 'FengWu-4DVar'...
# remote: Enumerating objects: 190, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 190 (delta 42), reused 49 (delta 26), pack-reused 120 (from 1)
# Receiving objects: 100% (190/190), 84.57 MiB | 34.93 MiB/s, done.
# Resolving deltas: 100% (86/86), done.
# Updating files: 100% (46/46), done.

# %%
# !cd "./FengWu-4DVar/" && git fetch && git pull && pip install -r requirements.txt
# Out:
# Already up to date.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# Ignoring colorama: markers 'python_version == "3.11" and platform_system == "Windows" or python_version >= "3.12" and python_version < "3.13" and platform_system == "Windows"' don't match your environment
# Ignoring pyreadline3: markers 'python_version == "3.11" and sys_platform == "win32" or python_version >= "3.12" and python_version < "3.13" and sys_platform == "win32"' don't match your environment
# Ignoring regex: markers 'python_version == "3.11" and sys_platform == "win32" or python_version >= "3.12" and python_version < "3.13" and sys_platform == "win32"' don't match your environment
# Ignoring setuptools: markers 'python_version >= "3.12" and python_version < "3.13"' don't match your environment
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 75.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 45.5 MB/s eta 0:00:00
# ...

# %%
# !cd "./FengWu-4DVar/" && git fetch && git pull --rebase && git checkout "main"

# !cd "./FengWu-4DVar/" \
    && export ONNX_MODEL_PATH="/content/drive/MyDrive/fengwu_v2.onnx" \
    && export GCLOUD_BUCKET="gs://gcp-public-data-arco-era5/ar/1959-2022-full_37-1h-0p25deg-chunk-1.zarr-v2" \
    && export BASE_RESULT_DIR="/content/drive/MyDrive/da_cycle_results" \
    && python3 "cyclic_da.py" --start_time="2020-10-01 00:00:00" --end_time="2020-10-02 00:00:00"
# Out:
# Already up to date.
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# q tensor([[4.8653e-03, 7.1497e-03, 3.8615e-04, 4.7372e-04, 1.6096e-04, 8.4428e-05,
#          4.2440e-05, 3.3492e-05, 3.2595e-05, 4.0589e-05, 5.2182e-05, 6.8263e-05,
#          8.7182e-05, 1.3917e-04, 2.7186e-04, 3.8853e-04, 4.6173e-04, 1.0257e-02,
#          1.9931e-02, 3.5178e-02, 3.1997e-02, 2.8688e-02, 2.3017e-02, 1.7420e-02,
#          1.2343e-02, 8.3148e-03, 7.0368e-03, 4.6282e-03, 2.2353e-03, 8.3795e-04,
#          2.6631e-03, 2.5461e-03, 1.9826e-03, 1.9017e-03, 2.1172e-03, 2.4159e-03,
#          2.8606e-03, 2.9815e-03, 3.3537e-03, 4.0234e-03, 5.0177e-03, 5.0661e-03,
#          5.5414e-03, 5.1012e-03, 5.2190e-03, 4.4055e-03, 3.7669e-03, 3.6650e-03,
#          3.8618e-03, 4.5664e-03, 5.0791e-03, 5.8960e-03, 7.0086e-03, 8.8165e-03,
#          8.6020e-03, 8.1127e-03, 1.3663e-03, 4.0805e-04, 6.8399e-04, 1.7330e-03,
# ...

# %%
from datetime import datetime

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
dest_folder = f"/content/drive/MyDrive/da_cycle_results_{timestamp}/"

# !mkdir -p "{dest_folder}" && cp -rf "./FengWu-4DVar/da_cycle_results/" "{dest_folder}"
